# %%
path = "/Users/82105/desktop/kg_itbank/python_study/data/nomad_data"

# %%
import pandas as pd
import os
marathon_2015_2017 = pd.read_csv(os.path.join(path,"marathon_total.csv"))
# Out:
# C:\Users\82105\AppData\Local\Continuum\anaconda3\envs\tf2.0-gpu\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid")

# %%
df = marathon_2015_2017

# %%
df.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  5520  6479  7359   296           7757        1       1
# 1  3628  ...  5519  6479  7362   298           7788        2       2
# 2  3629  ...  5520  6479  7381   299           7822        3       3
# 3  3629  ...  5520  6483  7427   300           7847        4       4
# 4  3628  ...  5520  6479  7407   300           7849        5       5
#
#    Division  Year  Unnamed: 8
# 0         1  2015         NaN
# ...

# %%
USA_runner = df[df["Country"]=="USA"]

# %%
USA_runner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64474 entries, 6 to 79637
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           64474 non-null  object
#  1   Age            64474 non-null  int64
#  2   M/F            64474 non-null  object
#  3   City           64474 non-null  object
#  4   State          64474 non-null  object
#  5   Country        64474 non-null  object
#  6   5K             64474 non-null  int64
#  7   10K            64474 non-null  int64
#  8   15K            64474 non-null  int64
#  9   20K            64474 non-null  int64
#  10  Half           64474 non-null  int64
#  11  25K            64474 non-null  int64
#  12  30K            64474 non-null  int64
#  13  35K            64474 non-null  int64
#  14  40K            64474 non-null  int64
#  15  Pace           64474 non-null  int64
#  16  Official Time  64474 non-null  int64
#  17  Overall        64474 non-null  int64
# ...

# %%
plt.figure(figsize=(30,10))

# %%
plt.figure(figsize=(30,10))
runner_state = sns.countplot("State",data=df)
runner_state.set_title("Number of Runner by State - USA" ,fontsize=18)
runner_state.set_xlabel("State",fontdict={"size":16})
runner_state.set_ylabel("Number of Runner",fontdict={"size":16})
plt.show()

# %%
plt.figure(figsize=(30,10))
runner_state = sns.countplot("State",data=df,hue="M/F",palette={'F':'r',"M":'b'})
runner_state.set_title("Number of Runner by State - USA" ,fontsize=18)
runner_state.set_xlabel("State",fontdict={"size":16})
runner_state.set_ylabel("Number of Runner",fontdict={"size":16})
plt.show()

# %%
# 바차트로도 추세 확인 가능
plt.figure(figsize=(30,10))
runner_state = sns.countplot("State",data=df,hue="Year")
runner_state.set_title("Number of Runner by State - USA" ,fontsize=18)
runner_state.set_xlabel("State",fontdict={"size":16})
runner_state.set_ylabel("Number of Runner",fontdict={"size":16})
plt.show()

# %%
runner_1860 = df[df.Age.isin(range(18,60))]
runner_1860_counting = runner_1860['Age'].value_counts()

# %%
runner_1860.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73608 entries, 0 to 79637
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           73608 non-null  object
#  1   Age            73608 non-null  int64
#  2   M/F            73608 non-null  object
#  3   City           73607 non-null  object
#  4   State          65438 non-null  object
#  5   Country        73608 non-null  object
#  6   5K             73608 non-null  int64
#  7   10K            73608 non-null  int64
#  8   15K            73608 non-null  int64
#  9   20K            73608 non-null  int64
#  10  Half           73608 non-null  int64
#  11  25K            73608 non-null  int64
#  12  30K            73608 non-null  int64
#  13  35K            73608 non-null  int64
#  14  40K            73608 non-null  int64
#  15  Pace           73608 non-null  int64
#  16  Official Time  73608 non-null  int64
#  17  Overall        73608 non-null  int64
# ...

# %%
runner_age_sort=runner_age.sort_values(by='Age')

# %%
runner_age_sort
# Out:
#     Age  Count
# 18   18     62
# 19   19    137
# 20   20    264
# 21   21    489
# 22   22    701
# 23   23    920
# 24   24   1301
# 25   25   1539
# 26   26   1709
# 27   27   1755
# 28   28   1758
# 29   29   1906
# 30   30   1849
# 31   31   1779
# 32   32   1726
# 33   33   1834
# 34   34   1756
# 35   35   2327
# 36   36   2188
# 37   37   2108
# 38   38   2128
# 39   39   2101
# 40   40   2734
# 41   41   2494
# 42   42   2318
# 43   43   2265
# 44   44   2056
# 45   45   3236
# 46   46   3039
# 47   47   2566
# 48   48   2277
# 49   49   2018
# 50   50   2498
# 51   51   2124
# 52   52   1930
# 53   53   1730
# 54   54   1433
# 55   55   1920
# 56   56   1514
# 57   57   1287
# 58   58   1044
# 59   59    788

# %%
plt.bar(runner_age_sort.Age,runner_age_sort.Count)
# Out:
# <BarContainer object of 42 artists>

# %%
x = runner_age_sort.index
x = [str(i) for i in x]
y = runner_age_sort['Count'].values
ratio = y / y.sum()
ratio_sum = ratio.cumsum()

# %%
runner_age =pd.DataFrame({
    'Age':runner_1860_counting.index,
    'Count':runner_1860_counting
})

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.bar(x,y)
ax_twin = ax.twinx()
ax_twin.plot(x,ratio_sum,'-ro',alpha=0.5)

ranges = ax_twin.get_yticks()
ax_twin.set_yticklabels(['{:.1%}'.format(x) for x in ranges])

ratio_sum_percentages = ["{:.0%}".format(i) for i in ratio_sum]
for i, txt in enumerate(ratio_sum_percentages):
    ax_twin.annotate(txt,(x[i],ratio_sum[i]),fontsize=14)
ax.set_xlabel("Age",fontdict={"size":16})
ax.set_ylabel("Number of runner", fontdict={"size":16})
plt.title("Pareto Chart - Number of runner by Age",fontsize=18)
plt.show()



plt.show()
