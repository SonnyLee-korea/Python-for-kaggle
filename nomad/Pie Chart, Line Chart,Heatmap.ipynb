# %%
import pandas as  pd
import numpy as np
import os

# %%
os.listdir('../data/nomad_data/')
# Out:
# ['marathon_2015_2017',
#  'marathon_2015_2017.csv',
#  'marathon_2015_2017_qualifying.csv',
#  'marathon_qualifying_time.csv',
#  'marathon_results_2015.csv',
#  'marathon_results_2016.csv',
#  'marathon_results_2017.csv',
#  'marathon_total.csv']

# %%
df = pd.read_csv('../data/nomad_data/marathon_total.csv')
# Out:
# C:\Users\82105\AppData\Local\Continuum\anaconda3\envs\tf2.0-gpu\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import matplotlib.pyplot as plt
labels = "Male","Female"
explode = (0,0.1)

# %%
df.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  5520  6479  7359   296           7757        1       1
# 1  3628  ...  5519  6479  7362   298           7788        2       2
# 2  3629  ...  5520  6479  7381   299           7822        3       3
# 3  3629  ...  5520  6483  7427   300           7847        4       4
# 4  3628  ...  5520  6479  7407   300           7849        5       5
#
#    Division  Year  Unnamed: 8
# 0         1  2015         NaN
# 1         2  2015         NaN
# 2         3  2015         NaN
# 3         4  2015         NaN
# 4         5  2015         NaN
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(7,7))
plt.pie(df['M/F'].value_counts(),explode=explode,labels=labels,
       startangle=90,shadow=True,autopct='%.1f')
plt.title('Male vs Female',fontsize=18)
plt.show()

# %%
df.head()
# Out:
#                     Name  Age M/F         City State Country   5K   10K   15K  \
# 0         Desisa, Lelisa   25   M         Ambo   NaN     ETH  883  1783  2697
# 1  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH  883  1783  2698
# 2         Chebet, Wilson   29   M     Marakwet   NaN     KEN  883  1783  2697
# 3       Kipyego, Bernard   28   M      Eldoret   NaN     KEN  883  1784  2701
# 4          Korir, Wesley   32   M       Kitale   NaN     KEN  883  1784  2698
#
#     20K  ...   30K   35K   40K  Pace  Official Time  Overall  Gender  \
# 0  3629  ...  5520  6479  7359   296           7757        1       1
# 1  3628  ...  5519  6479  7362   298           7788        2       2
# 2  3629  ...  5520  6479  7381   299           7822        3       3
# 3  3629  ...  5520  6483  7427   300           7847        4       4
# 4  3628  ...  5520  6479  7407   300           7849        5       5
#
#    Division  Year  Unnamed: 8
# 0         1  2015         NaN
# 1         2  2015         NaN
# 2         3  2015         NaN
# 3         4  2015         NaN
# 4         5  2015         NaN
#
# [5 rows x 22 columns]

# %%
df = pd.DataFrame(df,columns=['5K','10K','15K','Half','25K','30K','35K','40K','Official Time'])

# %%
df.head()
# Out:
#     5K   10K   15K  Half   25K   30K   35K   40K  Official Time
# 0  883  1783  2697  3842  4567  5520  6479  7359           7757
# 1  883  1783  2698  3841  4567  5519  6479  7362           7788
# 2  883  1783  2697  3842  4567  5520  6479  7381           7822
# 3  883  1784  2701  3842  4567  5520  6483  7427           7847
# 4  883  1784  2698  3841  4567  5520  6479  7407           7849

# %%
df.insert(0,'Rank',range(1,1+len(df)))

# %%
top100 = df[0:101]

# %%
xData = top100.Rank

# %%
y_full = top100['Official Time']
y_30k = top100['30K']
y_Half = top100['Half']
y_10k = top100['10K']

# %%
plt.figure(figsize=(20,10))
plt.plot(xData,y_full)
plt.plot(xData,y_30k)
plt.plot(xData,y_Half)
plt.plot(xData,y_10k)

# %%
df = pd.read_csv('../data/nomad_data/marathon_total.csv')
# Out:
# C:\Users\82105\AppData\Local\Continuum\anaconda3\envs\tf2.0-gpu\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
male = df[df['M/F']=='M']
female = df[df['M/F']=='F']

# %%
male
# Out:
#                         Name  Age M/F          City State Country    5K   10K  \
# 0             Desisa, Lelisa   25   M          Ambo   NaN     ETH   883  1783
# 1      Tsegay, Yemane Adhane   30   M   Addis Ababa   NaN     ETH   883  1783
# 2             Chebet, Wilson   29   M      Marakwet   NaN     KEN   883  1783
# 3           Kipyego, Bernard   28   M       Eldoret   NaN     KEN   883  1784
# 4              Korir, Wesley   32   M        Kitale   NaN     KEN   883  1784
# ...                      ...  ...  ..           ...   ...     ...   ...   ...
# 79631       Leroy, Stefan M.   25   M       Jupiter    FL     USA  2398  5153
# 79632         Quinn, Adam H.   19   M       Belmont    MI     USA  2114  4233
# 79634     Avelino, Andrew R.   25   M  Fayetteville    NC     USA  1923  3933
# 79636           Reilly, Bill   64   M      New York    NY     USA  2434  5239
# 79637          Rigsby, Scott   48   M    Alpharetta    GA     USA  2376  4632
#
#         15K    20K  ...    30K    35K    40K  Pace  Official Time  Overall  \
# 0      2697   3629  ...   5520   6479   7359   296           7757        1
# 1      2698   3628  ...   5519   6479   7362   298           7788        2
# 2      2697   3629  ...   5520   6479   7381   299           7822        3
# 3      2701   3629  ...   5520   6483   7427   300           7847        4
# 4      2698   3628  ...   5520   6479   7407   300           7849        5
# ...     ...    ...  ...    ...    ...    ...   ...            ...      ...
# 79631  7821  10867  ...  17380  20571  23668   953          24971    26405
# 79632  6470   9238  ...  16979  19995  24171   972          25473    26406
# 79634  6737  10181  ...  17401  21228  24861  1000          26219    26408
# 79636  8237  11500  ...  18429  21967  24968  1009          26444    26410
# 79637  7210  10735  ...  20233  23947  27683  1095          28694    26411
#
#        Gender  Division  Year  Unnamed: 8
# 0           1         1  2015         NaN
# 1           2         2  2015         NaN
# 2           3         3  2015         NaN
# 3           4         4  2015         NaN
# 4           5         5  2015         NaN
# ...       ...       ...   ...         ...
# 79631   14434      4772  2017         NaN
# 79632   14435      4773  2017         NaN
# 79634   14436      4774  2017         NaN
# 79636   14437      1043  2017         NaN
# 79637   14438      2553  2017         NaN
#
# [43482 rows x 22 columns]

# %%
plt.figure(figsize=(20,20))
x_male = male.Age
y_male = male['Official Time']
x_female = female.Age
y_female = female['Official Time']

# %%
plt.figure(figsize=(20,20))
plt.plot(x_male,y_male,'.',color='b',alpha=0.3)
plt.plot(x_female,y_female,'.',color='r',alpha=0.3)
plt.show()

# %%
os.listdir('../data/nomad_data')
# Out:
# ['marathon_2015_2017',
#  'marathon_2015_2017.csv',
#  'marathon_2015_2017_qualifying.csv',
#  'marathon_qualifying_time.csv',
#  'marathon_results_2015.csv',
#  'marathon_results_2016.csv',
#  'marathon_results_2017.csv',
#  'marathon_total.csv']

# %%
df = pd.read_csv('../data/nomad_data/marathon_results_2017.csv')

# %%
df = df.drop(['Unnamed: 0','Bib','Name','Age','City','State','Country'],axis=1)

# %%
df['5K'] = pd.to_timedelta(df['5K'])
df['10K'] = pd.to_timedelta(df['10K'])
df['15K'] = pd.to_timedelta(df['15K'])
df['20K'] = pd.to_timedelta(df['20K'])
df['25K'] = pd.to_timedelta(df['25K'])
df['30K'] = pd.to_timedelta(df['30K'])
df['35K'] = pd.to_timedelta(df['35K'])
df['40K'] = pd.to_timedelta(df['40K'])

# %%
df['5K'] = df['5K'].astype('m8[s]').astype(np.int64)
df['10K'] = df['10K'].astype('m8[s]').astype(np.int64)
df['15K'] = df['15K'].astype('m8[s]').astype(np.int64)
df['20K'] = df['20K'].astype('m8[s]').astype(np.int64)
df['25K'] = df['25K'].astype('m8[s]').astype(np.int64)
df['30K'] = df['30K'].astype('m8[s]').astype(np.int64)
df['35K'] = df['35K'].astype('m8[s]').astype(np.int64)
df['40K'] = df['40K'].astype('m8[s]').astype(np.int64)

# %%
df.head()
# Out:
#   M/F Citizen Unnamed: 9   5K   10K   15K   20K     Half   25K   30K   35K  \
# 0   M     NaN        NaN  925  1828  2744  3675  1:04:35  4619  5581  6499
# 1   M     NaN        NaN  924  1827  2744  3675  1:04:35  4619  5581  6499
# 2   M     NaN        NaN  925  1829  2744  3676  1:04:36  4620  5581  6511
# 3   M     NaN        NaN  925  1829  2744  3679  1:04:45  4620  5581  6538
# 4   M     NaN        NaN  925  1828  2744  3675  1:04:35  4619  5581  6521
#
#     40K     Pace Proj Time Official Time  Overall  Gender  Division
# 0  7373  0:04:57         -       2:09:37        1       1         1
# 1  7394  0:04:58         -       2:09:58        2       2         2
# 2  7418  0:04:59         -       2:10:28        3       3         3
# 3  7475  0:05:03         -       2:12:08        4       4         4
# 4  7500  0:05:04         -       2:12:35        5       5         5

# %%
import seaborn as sns

# %%
df = pd.read_csv('../data/nomad_data/marathon_total.csv')
# Out:
# C:\Users\82105\AppData\Local\Continuum\anaconda3\envs\tf2.0-gpu\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df['Age']<=60]

# %%
df
# Out:
#                         Name  Age M/F          City State Country    5K   10K  \
# 0             Desisa, Lelisa   25   M          Ambo   NaN     ETH   883  1783
# 1      Tsegay, Yemane Adhane   30   M   Addis Ababa   NaN     ETH   883  1783
# 2             Chebet, Wilson   29   M      Marakwet   NaN     KEN   883  1783
# 3           Kipyego, Bernard   28   M       Eldoret   NaN     KEN   883  1784
# 4              Korir, Wesley   32   M        Kitale   NaN     KEN   883  1784
# ...                      ...  ...  ..           ...   ...     ...   ...   ...
# 79631       Leroy, Stefan M.   25   M       Jupiter    FL     USA  2398  5153
# 79632         Quinn, Adam H.   19   M       Belmont    MI     USA  2114  4233
# 79634     Avelino, Andrew R.   25   M  Fayetteville    NC     USA  1923  3933
# 79635        Hantel, Johanna   57   F       Malvern    PA     USA  3191  6216
# 79637          Rigsby, Scott   48   M    Alpharetta    GA     USA  2376  4632
#
#         15K    20K  ...    30K    35K    40K  Pace  Official Time  Overall  \
# 0      2697   3629  ...   5520   6479   7359   296           7757        1
# 1      2698   3628  ...   5519   6479   7362   298           7788        2
# 2      2697   3629  ...   5520   6479   7381   299           7822        3
# 3      2701   3629  ...   5520   6483   7427   300           7847        4
# 4      2698   3628  ...   5520   6479   7407   300           7849        5
# ...     ...    ...  ...    ...    ...    ...   ...            ...      ...
# 79631  7821  10867  ...  17380  20571  23668   953          24971    26405
# 79632  6470   9238  ...  16979  19995  24171   972          25473    26406
# 79634  6737  10181  ...  17401  21228  24861  1000          26219    26408
# 79635  9156      0  ...  18397  21633  24878  1007          26377    26409
# 79637  7210  10735  ...  20233  23947  27683  1095          28694    26411
#
#        Gender  Division  Year  Unnamed: 8
# 0           1         1  2015         NaN
# 1           2         2  2015         NaN
# 2           3         3  2015         NaN
# 3           4         4  2015         NaN
# 4           5         5  2015         NaN
# ...       ...       ...   ...         ...
# 79631   14434      4772  2017         NaN
# 79632   14435      4773  2017         NaN
# 79634   14436      4774  2017         NaN
# 79635   11973       698  2017         NaN
# 79637   14438      2553  2017         NaN
#
# [74945 rows x 22 columns]

# %%
df = df.groupby('Age')['M/F'].value_counts().unstack().fillna(0)

# %%
f,ax  =plt.subplots(figsize=(10,20))
sns.heatmap(df,annot=True,fmt='d',linewidths=.5,ax=ax,cmap='Blues_r')
plt.show()
