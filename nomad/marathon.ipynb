# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\82105\\Desktop\\kg_itbank\\python_study\\nomad'

# %%
os.listdir('/Users/82105/desktop/kg_itbank/python_study/data/nomad_data')
# Out:
# ['marathon_2015_2017.csv',
#  'marathon_2015_2017_qualifying.csv',
#  'marathon_qualifying_time.csv',
#  'marathon_results_2015.csv',
#  'marathon_results_2016.csv',
#  'marathon_results_2017.csv']

# %%
path = "/Users/82105/desktop/kg_itbank/python_study/data/nomad_data"

# %%
marathon_2017 = pd.read_csv(os.path.join(path,"marathon_results_2017.csv"))

# %%
marathon_2017.head()
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      25K      30K      35K      40K     Pace  \
# 0     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1     NaN        NaN  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2     NaN        NaN  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3     NaN        NaN  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4     NaN        NaN  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
len(marathon_2017.columns)
# Out:
# 25

# %%
marathon_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     26410 non-null  int64
#  1   Bib            26410 non-null  object
#  2   Name           26410 non-null  object
#  3   Age            26410 non-null  int64
#  4   M/F            26410 non-null  object
#  5   City           26410 non-null  object
#  6   State          22815 non-null  object
#  7   Country        26410 non-null  object
#  8   Citizen        1254 non-null   object
#  9   Unnamed: 9     91 non-null     object
#  10  5K             26410 non-null  object
#  11  10K            26410 non-null  object
#  12  15K            26410 non-null  object
#  13  20K            26410 non-null  object
#  14  Half           26410 non-null  object
#  15  25K            26410 non-null  object
#  16  30K            26410 non-null  object
# ...

# %%
marathon_2017.isnull().sum()
# Out:
# Unnamed: 0           0
# Bib                  0
# Name                 0
# Age                  0
# M/F                  0
# City                 0
# State             3595
# Country              0
# Citizen          25156
# Unnamed: 9       26319
# 5K                   0
# 10K                  0
# 15K                  0
# 20K                  0
# Half                 0
# 25K                  0
# 30K                  0
# 35K                  0
# 40K                  0
# Pace                 0
# Proj Time            0
# Official Time        0
# Overall              0
# Gender               0
# Division             0
# dtype: int64

# %%
marathon_2017.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
marathon_2017_clean = marathon_2017.drop(['Unnamed: 0','Bib','Unnamed: 9'],axis=1)

# %%
marathon_2017_clean.head()
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      25K      30K      35K      40K     Pace  \
# 0  0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 1  0:30:27  0:45:44  ...  1:16:59  1:33:01  1:48:19  2:03:14  0:04:58
# 2  0:30:29  0:45:44  ...  1:17:00  1:33:01  1:48:31  2:03:38  0:04:59
# 3  0:30:29  0:45:44  ...  1:17:00  1:33:01  1:48:58  2:04:35  0:05:03
# 4  0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
#
#   Proj Time Official Time Overall Gender  Division
# ...

# %%
marathon_2017_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26410 non-null  object
#  1   Age            26410 non-null  int64
#  2   M/F            26410 non-null  object
#  3   City           26410 non-null  object
#  4   State          22815 non-null  object
#  5   Country        26410 non-null  object
#  6   Citizen        1254 non-null   object
#  7   5K             26410 non-null  object
#  8   10K            26410 non-null  object
#  9   15K            26410 non-null  object
#  10  20K            26410 non-null  object
#  11  Half           26410 non-null  object
#  12  25K            26410 non-null  object
#  13  30K            26410 non-null  object
#  14  35K            26410 non-null  object
#  15  40K            26410 non-null  object
#  16  Pace           26410 non-null  object
# ...

# %%
marathon_2017_clean['Senior'] = marathon_2017_clean.Age > 60

# %%
print(marathon_2017_clean)
# Out:
#                            Name  Age M/F           City State Country Citizen  \
# 0               Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN
# 1                   Rupp, Galen   30   M       Portland    OR     USA     NaN
# 2                 Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN
# 3              Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN
# 4                Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN
# ...                         ...  ...  ..            ...   ...     ...     ...
# 26405  Steinbach, Paula Eyvonne   61   F        Ontario    CA     USA     NaN
# 26406        Avelino, Andrew R.   25   M   Fayetteville    NC     USA     NaN
# 26407           Hantel, Johanna   57   F        Malvern    PA     USA     NaN
# 26408              Reilly, Bill   64   M       New York    NY     USA     NaN
# 26409             Rigsby, Scott   48   M     Alpharetta    GA     USA     NaN
#
# ...

# %%
marathon_2017_clean['Year'] = "2017"

# %%
print(marathon_2017_clean.head())
# Out:
#                Name  Age M/F           City State Country Citizen       5K  \
# 0   Kirui, Geoffrey   24   M       Keringet   NaN     KEN     NaN  0:15:25
# 1       Rupp, Galen   30   M       Portland    OR     USA     NaN  0:15:24
# 2     Osako, Suguru   25   M   Machida-City   NaN     JPN     NaN  0:15:25
# 3  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA     NaN  0:15:25
# 4    Chebet, Wilson   31   M       Marakwet   NaN     KEN     NaN  0:15:25
#
#        10K      15K  ...      35K      40K     Pace Proj Time Official Time  \
# 0  0:30:28  0:45:44  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
# 1  0:30:27  0:45:44  ...  1:48:19  2:03:14  0:04:58         -       2:09:58
# 2  0:30:29  0:45:44  ...  1:48:31  2:03:38  0:04:59         -       2:10:28
# 3  0:30:29  0:45:44  ...  1:48:58  2:04:35  0:05:03         -       2:12:08
# 4  0:30:28  0:45:44  ...  1:48:41  2:05:00  0:05:04         -       2:12:35
#
#   Overall Gender Division Senior  Year
# ...

# %%
print(marathon_2017_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26410 non-null  object
#  1   Age            26410 non-null  int64
#  2   M/F            26410 non-null  object
#  3   City           26410 non-null  object
#  4   State          22815 non-null  object
#  5   Country        26410 non-null  object
#  6   Citizen        1254 non-null   object
#  7   5K             26410 non-null  object
#  8   10K            26410 non-null  object
#  9   15K            26410 non-null  object
#  10  20K            26410 non-null  object
#  11  Half           26410 non-null  object
#  12  25K            26410 non-null  object
#  13  30K            26410 non-null  object
#  14  35K            26410 non-null  object
#  15  40K            26410 non-null  object
#  16  Pace           26410 non-null  object
# ...

# %%
names = marathon_2017_clean.Name

print(names)
# Out:
# 0                 Kirui, Geoffrey
# 1                     Rupp, Galen
# 2                   Osako, Suguru
# 3                Biwott, Shadrack
# 4                  Chebet, Wilson
#                    ...
# 26405    Steinbach, Paula Eyvonne
# 26406          Avelino, Andrew R.
# 26407             Hantel, Johanna
# 26408                Reilly, Bill
# 26409               Rigsby, Scott
# Name: Name, Length: 26410, dtype: object

# %%
Official_Time = marathon_2017_clean['Official Time']
print(Official_Time)
# Out:
# 0        2:09:37
# 1        2:09:58
# 2        2:10:28
# 3        2:12:08
# 4        2:12:35
#           ...
# 26405    7:09:39
# 26406    7:16:59
# 26407    7:19:37
# 26408    7:20:44
# 26409    7:58:14
# Name: Official Time, Length: 26410, dtype: object

# %%
print(marathon_2017_clean.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26410 entries, 0 to 26409
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26410 non-null  object
#  1   Age            26410 non-null  int64
#  2   M/F            26410 non-null  object
#  3   City           26410 non-null  object
#  4   State          22815 non-null  object
#  5   Country        26410 non-null  object
#  6   Citizen        1254 non-null   object
#  7   5K             26410 non-null  object
#  8   10K            26410 non-null  object
#  9   15K            26410 non-null  object
#  10  20K            26410 non-null  object
#  11  Half           26410 non-null  object
#  12  25K            26410 non-null  object
#  13  30K            26410 non-null  object
#  14  35K            26410 non-null  object
#  15  40K            26410 non-null  object
#  16  Pace           26410 non-null  object
# ...

# %%
seniors = marathon_2017_clean.Age>60
print(seniors)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 26405     True
# 26406    False
# 26407    False
# 26408     True
# 26409    False
# Name: Age, Length: 26410, dtype: bool

# %%
marathon_2017_clean[seniors]
# Out:
#                            Name  Age M/F           City State Country Citizen  \
# 1676          Bariyanga, Joseph   61   M       Mililani    HI     USA     NaN
# 1802            Funk, Dennis L.   61   M          Greer    SC     USA     NaN
# 1949          Beasley, Steve G.   61   M       Goderich    ON     CAN     NaN
# 2731                Dykes, Gene   69   M    Bala Cynwyd    PA     USA     NaN
# 2863          Standerfer, Joe L   61   M  Winston-Salem    NC     USA     NaN
# ...                         ...  ...  ..            ...   ...     ...     ...
# 26397        Coffman, Steven D.   69   M  East Sandwich    MA     USA     NaN
# 26398           Scholtz, Theo E   70   M          Wylie    TX     USA     NaN
# 26401       Elliott, Gregory J.   68   M        Chicago    IL     USA     NaN
# 26405  Steinbach, Paula Eyvonne   61   F        Ontario    CA     USA     NaN
# 26408              Reilly, Bill   64   M       New York    NY     USA     NaN
#
# ...

# %%
KEN_runner = marathon_2017_clean[marathon_2017_clean['Country']=='KEN']

# %%
KEN_runner
# Out:
#                    Name  Age M/F         City State Country Citizen       5K  \
# 0       Kirui, Geoffrey   24   M     Keringet   NaN     KEN     NaN  0:15:25
# 4        Chebet, Wilson   31   M     Marakwet   NaN     KEN     NaN  0:15:25
# 14        Korir, Wesley   34   M       Kitale   NaN     KEN     NaN  0:15:24
# 17      Mutai, Emmanuel   32   M       Lessos   NaN     KEN     NaN  0:15:24
# 20       Kiplagat, Edna   37   F  Uasin Gishu   NaN     KEN     NaN  0:17:46
# 43      Cherono, Gladys   33   F      Kericho   NaN     KEN     NaN  0:17:45
# 53  Kipketer, Valentine   24   F        Keiyo   NaN     KEN     NaN  0:17:45
# 69       Kosgei, Brigid   23   F      Kapsait   NaN     KEN     NaN  0:17:45
#
#         10K      15K  ...      25K      30K      35K      40K     Pace  \
# 0   0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:19  2:02:53  0:04:57
# 4   0:30:28  0:45:44  ...  1:16:59  1:33:01  1:48:41  2:05:00  0:05:04
# ...

# %%
def to_seconds(record):
    hms = record.str.split(':',n=2,expand=True)
    return hms[0].astype(int)*3600 + hms[1].astype(int)*60 + hms[2].astype(int)

# %%
marathon_2017['Official Time Sec'] = to_seconds(marathon_2017['Official Time'])

# %%
print(marathon_2017.head())
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      30K      35K      40K     Pace Proj Time  \
# 0     NaN        NaN  ...  1:33:01  1:48:19  2:02:53  0:04:57         -
# 1     NaN        NaN  ...  1:33:01  1:48:19  2:03:14  0:04:58         -
# 2     NaN        NaN  ...  1:33:01  1:48:31  2:03:38  0:04:59         -
# 3     NaN        NaN  ...  1:33:01  1:48:58  2:04:35  0:05:03         -
# 4     NaN        NaN  ...  1:33:01  1:48:41  2:05:00  0:05:04         -
#
#   Official Time Overall Gender Division Official Time Sec
# ...

# %%
import numpy as np

# %%
marathon_2017["Official Time Sec"] = pd.to_timedelta(marathon_2017['Official Time'])
marathon_2017["Official Time New"] = marathon_2017["Official Time Sec"].astype('m8[s]').astype(np.int64)

# %%
print(marathon_2017.head())
# Out:
#    Unnamed: 0 Bib              Name  Age M/F           City State Country  \
# 0           0  11   Kirui, Geoffrey   24   M       Keringet   NaN     KEN
# 1           1  17       Rupp, Galen   30   M       Portland    OR     USA
# 2           2  23     Osako, Suguru   25   M   Machida-City   NaN     JPN
# 3           3  21  Biwott, Shadrack   32   M  Mammoth Lakes    CA     USA
# 4           4   9    Chebet, Wilson   31   M       Marakwet   NaN     KEN
#
#   Citizen Unnamed: 9  ...      35K      40K     Pace Proj Time Official Time  \
# 0     NaN        NaN  ...  1:48:19  2:02:53  0:04:57         -       2:09:37
# 1     NaN        NaN  ...  1:48:19  2:03:14  0:04:58         -       2:09:58
# 2     NaN        NaN  ...  1:48:31  2:03:38  0:04:59         -       2:10:28
# 3     NaN        NaN  ...  1:48:58  2:04:35  0:05:03         -       2:12:08
# 4     NaN        NaN  ...  1:48:41  2:05:00  0:05:04         -       2:12:35
#
# ...

# %%
marathon_2017['Official Time New'].astype('int32')
# Out:
# 0         7777
# 1         7798
# 2         7828
# 3         7928
# 4         7955
#          ...
# 26405    25779
# 26406    26219
# 26407    26377
# 26408    26444
# 26409    28694
# Name: Official Time New, Length: 26410, dtype: int32

# %%
path
# Out:
# '/Users/82105/desktop/kg_itbank/python_study/data/nomad_data'

# %%
marathon_2015 = pd.read_csv(os.path.join(path,"marathon_results_2015.csv"))
marathon_2016 = pd.read_csv(os.path.join(path,"marathon_results_2016.csv"))
marathon_2017 = pd.read_csv(os.path.join(path,"marathon_results_2017.csv"))

# %%
marathon_2015_2017 = pd.concat([marathon_2015,marathon_2016,marathon_2017],ignore_index=True,sort=False).set_index('Official Time')

# %%
print(marathon_2015_2017.describe())
# Out:
#          Unnamed: 0           Age       Overall        Gender      Division
# count  53008.000000  79638.000000  79638.000000  79638.000000  79638.000000
# mean   13251.666692     42.415166  13273.683417   6693.365064   1618.782792
# std     7651.406646     11.355453   7663.512720   3927.594786   1448.369424
# min        0.000000     18.000000      1.000000      1.000000      1.000000
# 25%     6625.750000     34.000000   6637.250000   3319.000000    510.000000
# 50%    13251.500000     42.000000  13273.500000   6637.000000   1179.500000
# 75%    19877.250000     50.000000  19910.000000   9955.000000   2219.000000
# max    26597.000000     84.000000  26629.000000  14581.000000   6004.000000

# %%
marathon_2015_2017
# Out:
#                Unnamed: 0    Bib                      Name  Age M/F  \
# Official Time
# 2:09:17               0.0      3            Desisa, Lelisa   25   M
# 2:09:48               1.0      4     Tsegay, Yemane Adhane   30   M
# 2:10:22               2.0      8            Chebet, Wilson   29   M
# 2:10:47               3.0     11          Kipyego, Bernard   28   M
# 2:10:49               4.0     10             Korir, Wesley   32   M
# ...                   ...    ...                       ...  ...  ..
# 7:09:39           26405.0  25166  Steinbach, Paula Eyvonne   61   F
# 7:16:59           26406.0  25178        Avelino, Andrew R.   25   M
# 7:19:37           26407.0  27086           Hantel, Johanna   57   F
# 7:20:44           26408.0  25268              Reilly, Bill   64   M
# 7:58:14           26409.0  25266             Rigsby, Scott   48   M
#
#                        City State Country Citizen Unnamed: 9  ...      25K  \
# ...

# %%
marathon_2015_2017.sort_values(by="Age",ascending=False)
# Out:
#                Unnamed: 0    Bib                 Name  Age M/F          City  \
# Official Time
# 6:04:07           26340.0  25269    Beiers, Katherine   84   F    Santa Cruz
# 4:51:41               NaN  25878       Wilson, Harold   83   M         Tyler
# 5:44:53               NaN  26142    Beiers, Katherine   83   F    Santa Cruz
# 4:44:39           22619.0  25134            Yoo, Jack   83   M       Chicago
# 4:18:00           21625.0  24564       Wilson, Harold   82   M         Tyler
# ...                   ...    ...                  ...  ...  ..           ...
# 4:34:58               NaN  29566    Bailey, Jordan E.   18   F        Quincy
# 3:20:23            4735.0   4496        Moore, Ryan D   18   M    North Bend
# 3:06:30            3885.0   6992  Altomari, Collin P.   18   M  Severna Park
# 3:06:22            3857.0  30062  Chhokra, Shubhankar   18   M     Cambridge
# 4:01:25           15931.0  30496   Pohl, Elizabeth S.   18   F        Weston
#
# ...

# %%
marathon_2015_2017.to_csv(os.path.join(path,"marathon_2015_2017"),index=None,header=True)

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79638 entries, 2:09:17 to 7:58:14
# Data columns (total 25 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53008 non-null  float64
#  1   Bib         79638 non-null  object
#  2   Name        79638 non-null  object
#  3   Age         79638 non-null  int64
#  4   M/F         79638 non-null  object
#  5   City        79637 non-null  object
#  6   State       70645 non-null  object
#  7   Country     79638 non-null  object
#  8   Citizen     3440 non-null   object
#  9   Unnamed: 9  158 non-null    object
#  10  5K          79638 non-null  object
#  11  10K         79638 non-null  object
#  12  15K         79638 non-null  object
#  13  20K         79638 non-null  object
#  14  Half        79638 non-null  object
#  15  25K         79638 non-null  object
#  16  30K         79638 non-null  object
#  17  35K         79638 non-null  object
#  18  40K         79638 non-null  object
# ...

# %%
marathon_2015 = pd.read_csv(os.path.join(path,"marathon_results_2015.csv"))
marathon_2016 = pd.read_csv(os.path.join(path,"marathon_results_2016.csv"))
marathon_2017 = pd.read_csv(os.path.join(path,"marathon_results_2017.csv"))

# %%
marathon_2015['Year'] = "2015"
marathon_2016['Year'] = "2016"
marathon_2017["Year"] = "2017"

# %%
marathon_2015.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division', 'Year'],
#       dtype='object')

# %%
marathon_2015_2017 = pd.concat([marathon_2015,marathon_2016,marathon_2017],ignore_index=True,sort=False)

# %%
marathon_2015_2017.drop(['Unnamed: 0',"Bib","Citizen","Unnamed: 9","Proj Time"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-c63fa9b326bb> in <module>
# ----> 1 marathon_2015_2017.drop(['Unnamed: 0',"Bib","Citizen","Unnamed: 9","Proj Time"],axis=1,inplace=True)
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf2.0-gpu\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\AppData\Local\Continuum\anaconda3\envs\tf2.0-gpu\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
# ...

# %%
marathon_2015_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79638 entries, 2:09:17 to 7:58:14
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        79638 non-null  object
#  1   Age         79638 non-null  int64
#  2   M/F         79638 non-null  object
#  3   City        79637 non-null  object
#  4   State       70645 non-null  object
#  5   Country     79638 non-null  object
#  6   5K          79638 non-null  object
#  7   10K         79638 non-null  object
#  8   15K         79638 non-null  object
#  9   20K         79638 non-null  object
#  10  Half        79638 non-null  object
#  11  25K         79638 non-null  object
#  12  30K         79638 non-null  object
#  13  35K         79638 non-null  object
#  14  40K         79638 non-null  object
#  15  Pace        79638 non-null  object
#  16  Overall     79638 non-null  int64
#  17  Gender      79638 non-null  int64
#  18  Division    79638 non-null  int64
# ...

# %%
marathon_2015_2017.columns
# Out:
# Index(['Name', 'Age', 'M/F', 'City', 'State', 'Country', '5K', '10K', '15K',
#        '20K', 'Half', '25K', '30K', '35K', '40K', 'Pace', 'Overall', 'Gender',
#        'Division', 'Year', 'Unnamed: 8'],
#       dtype='object')

# %%
def to_seconds(record):
    hms = record.str.split(':',n=2,expand=True)
    return hms[0].astype(int)*3600 + hms[1].astype(int)*60 + hms[2].astype(int)

# %%
def to_second(x):
    y = x.str.split(":",n=2,expand=True)
    return y[0].astype(int)*3600 + y[1].astype(int)*60 + y[2].astype(int)

# %%
marathon_2017['Official Time Sec'] = to_seconds(marathon_2017['Official Time'])

# %%
a = marathon_2015_2017["10K"].str.split(':',expand=True)
a
# Out:
#                0   1   2
# Official Time
# 2:09:17        0  29  43
# 2:09:48        0  29  43
# 2:10:22        0  29  43
# 2:10:47        0  29  44
# 2:10:49        0  29  44
# ...           ..  ..  ..
# 7:09:39        1  35  41
# 7:16:59        1  05  33
# 7:19:37        1  43  36
# 7:20:44        1  27  19
# 7:58:14        1  17  12
#
# [79638 rows x 3 columns]

# %%
marathon_2015_2017["5K"] = pd.to_timedelta(marathon_2015_2017['5K'])
marathon_2015_2017["10K"] = pd.to_timedelta(marathon_2015_2017['10K'])
marathon_2015_2017["15K"] = pd.to_timedelta(marathon_2015_2017['15K'])
marathon_2015_2017["20K"] = pd.to_timedelta(marathon_2015_2017['20K'])
marathon_2015_2017["Half"] = pd.to_timedelta(marathon_2015_2017['Half'])
marathon_2015_2017["25K"] = pd.to_timedelta(marathon_2015_2017['25K'])
marathon_2015_2017["30K"] = pd.to_timedelta(marathon_2015_2017['30K'])
marathon_2015_2017["35K"] = pd.to_timedelta(marathon_2015_2017['35K'])
marathon_2015_2017["40K"] = pd.to_timedelta(marathon_2015_2017['40K'])
marathon_2015_2017["Pace"] = pd.to_timedelta(marathon_2015_2017['Pace'])
marathon_2015_2017["Official Time"] = pd.to_timedelta(marathon_2015_2017['Official Time'])

marathon_2015_2017["5K"] = marathon_2015_2017['5K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["10K"] = marathon_2015_2017['10K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["15K"] = marathon_2015_2017['15K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["20K"] = marathon_2015_2017['20K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["Half"] = marathon_2015_2017['Half'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["25K"] = marathon_2015_2017['25K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["30K"] = marathon_2015_2017['30K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["35K"] = marathon_2015_2017['35K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["40K"] = marathon_2015_2017['40K'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["Pace"] = marathon_2015_2017['Pace'].astype('m8[s]').astype(np.int64)
marathon_2015_2017["Official Time"] = marathon_2015_2017['Official Time'].astype('m8[s]').astype(np.int64)

# %%
print(marathon_2015_2017.head())
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ...   35K   40K  Pace  Proj Time  Official Time  \
# 0     NaN        NaN  ...  6479  7359   296          -           7757
# 1     NaN        NaN  ...  6479  7362   298          -           7788
# 2     NaN        NaN  ...  6479  7381   299          -           7822
# 3     NaN        NaN  ...  6483  7427   300          -           7847
# 4     NaN        NaN  ...  6479  7407   300          -           7849
#
#    Overall  Gender  Division  Year  Unnamed: 8
# ...

# %%
marathon_2015_2017.to_csv(os.path.join(path,"marathon_total.csv"),index=None,header=True)

# %%
marathon_2015['5K'][0].find("-")
# Out:
# -1

# %%
int(marathon_2015["30K"][0].split(":")[0])
# Out:
# 1

# %%
to_second(marathon_2015["30K"][0])
# Out:
# 5520

# %%
def to_change(record):
    if(record.find("-") != -1):
        return record.replace("-",0)

# %%
def to_second(record):
    h = record.split(":")
    return int(h[0])*3600 + int(h[1])*60 + int(h[2])

# %%
marathon_2015["30K"] = [to_second(i) for i in marathon_2015["30K"]]

# %%
marathon_2015["30K"] = marathon_2015["30K"].apply(lambda x : x.replace("-","00:00:00"))

# %%
marathon_2015["30K"]
# Out:
# 0         5520
# 1         5519
# 2         5520
# 3         5520
# 4         5520
#          ...
# 26593    19184
# 26594    19918
# 26595    20336
# 26596    19871
# 26597    20624
# Name: 30K, Length: 26598, dtype: int64
